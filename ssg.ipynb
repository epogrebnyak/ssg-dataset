# %% [markdown]
# <a href="https://colab.research.google.com/github/epogrebnyak/ssg/blob/main/ssg.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv("https://raw.githubusercontent.com/epogrebnyak/ssg/main/data/ssg.csv")
df['stars'] = df.stars.divide(1000).round(1)
df
# Out:
#             name  ...                                               url
# 0           hugo  ...                 https://github.com/gohugoio/hugo/
# 1         gatsby  ...               https://github.com/gatsbyjs/gatsby/
# 2         jekyll  ...                 https://github.com/jekyll/jekyll/
# 3           hexo  ...                   https://github.com/hexojs/hexo/
# 4       vuepress  ...                https://github.com/vuejs/vuepress/
# 5         mkdocs  ...                 https://github.com/mkdocs/mkdocs/
# 6        pelican  ...            https://github.com/getpelican/pelican/
# 7       eleventy  ...                 https://github.com/11ty/eleventy/
# 8         mdBook  ...              https://github.com/rust-lang/mdBook/
# 9           zola  ...                  https://github.com/getzola/zola/
# 10        sphinx  ...             https://github.com/sphinx-doc/sphinx/
# 11        nikola  ...              https://github.com/getnikola/nikola/
# ...

# %%
import altair as alt
ch = (
    alt.Chart(
        df,
        title="Static site generators popularity",
    )
    .mark_bar()
    .encode(
        x=alt.X("stars", title="'000 stars on Github"),
        y=alt.Y(
            "name",
            sort=alt.EncodingSortField(field="stars", order="descending"),
            title="",
        ),
        color=alt.Color(
            "lang",
            legend=alt.Legend(title="Language"),
            scale=alt.Scale(scheme="tableau10"),
        ),
    )
)
ch.interactive()
# Out:
# alt.Chart(...)
